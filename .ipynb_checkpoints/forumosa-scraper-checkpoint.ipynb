# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
response = requests.get("https://tw.forumosa.com/top")
doc = BeautifulSoup(response.text, 'html.parser')

# %%
posts = doc.select('.topic-list-item')

# %%
for post in posts:
    print('-----')
    print(post.select_one('a').text)
    print(post.select_one('.category-name').text)
    print(post.select_one('a')['href'])
    print(post.select_one('.views').text.strip() + ' views')
    print('Last reply on ' + post.select('td')[-1].text.strip())
# Out:
# -----
# Warning for anyone considering using "Hello Taipei" to report illegal work activity
# Working in Taiwan
# https://tw.forumosa.com/t/warning-for-anyone-considering-using-hello-taipei-to-report-illegal-work-activity/207016
# 2113 views
# Last reply on May 23, 2021
# -----
# Thank You For A Real Good Time
# Testimonials
# https://tw.forumosa.com/t/thank-you-for-a-real-good-time/198723
# 693 views
# Last reply on November 13, 2020
# -----
# Good young people in Taiwan
# Living in Taiwan
# https://tw.forumosa.com/t/good-young-people-in-taiwan/203329
# 853 views
# Last reply on March 4, 2021
# -----
# I Was Accosted By Cops
# Living in Taiwan
# https://tw.forumosa.com/t/i-was-accosted-by-cops/201695
# 1749 views
# Last reply on January 24, 2021
# -----
# I would very much like an alternative forum that was much more heavily regulated
# Site Feedback
# https://tw.forumosa.com/t/i-would-very-much-like-an-alternative-forum-that-was-much-more-heavily-regulated/197770
# 4831 views
# ...
